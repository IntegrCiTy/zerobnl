# %%
import os
import pandas as pd

import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
[f for f in os.listdir() if "res_" in f]
# Out:
# ['res_line.csv', 'res_bus.csv']

# %%
res_line = pd.read_csv("res_line.csv").set_index(["time", "index"])
res_bus = pd.read_csv("res_bus.csv").set_index(["time", "index"])

# %%
fig, ax = plt.subplots()

res_line.loc[(slice(None), 0), "loading_percent"].plot(marker="o", linestyle="-", ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
